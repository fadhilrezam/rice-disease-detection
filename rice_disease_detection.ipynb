# %% [markdown]
# ## Load Libraries

# %%
import splitfolders
import os
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Modeling
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

# Model Evaluation
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Model Inference
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ## Load Dataset

# %%
splitfolders.ratio("rice_disease_dataset", output="output",
    seed=1337, ratio=(.7, .3), group_prefix=None, move=False)
# Out:
# Copying files: 240 files [00:00, 887.21 files/s]

# %%
train = 'output/train'
val = 'output/val'

# %% [markdown]
# ## EDA

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 2 folder and 0 images in output
# 3 folder and 0 images in output\train
# 0 folder and 64 images in output\train\blast
# 0 folder and 64 images in output\train\blight
# 0 folder and 64 images in output\train\tungro
# 3 folder and 0 images in output\val
# 0 folder and 24 images in output\val\blast
# 0 folder and 24 images in output\val\blight
# 0 folder and 24 images in output\val\tungro

# %%
train_data = image_dataset_from_directory(train)
val_data = image_dataset_from_directory(val)
# Out:
# Found 192 files belonging to 3 classes.
# Found 72 files belonging to 3 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['blast', 'blight', 'tungro']

# %% [markdown]
# ### Example of Images in Each Class

# %%
plt.figure(figsize=(20, 10))
for images, labels in train_data.take(1):
  for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Example How Data Augmented Looks Like

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.4),
])

# %%
for image, _ in train_data.take(1):
    plt.figure(figsize=(20, 10))
    first_image = image[0]
    for i in range(6):
        ax = plt.subplot(2, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0]/255)
        plt.axis('off')

# %% [markdown]
# ## Preprocessing (Making Pipeline)

# %%
tf.random.set_seed(46)

train_datagen = ImageDataGenerator(rescale = 1/255.0)
val_datagen = ImageDataGenerator(rescale = 1/255.0)
train_datagen_augmented = ImageDataGenerator(rescale=1/255.0,
                                             rotation_range=0.2,
                                             zoom_range=0.2,
                                             width_shift_range=0.2,
                                             height_shift_range=0.2,
                                             horizontal_flip=True,
                                             shear_range=0.2,
                                             brightness_range = (0.2, 0.8))

# %%
train_data = train_datagen.flow_from_directory(train,
                                               batch_size=20,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle = True,
                                               seed=42)

val_data = val_datagen.flow_from_directory(val,
                                               batch_size=20,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle = False,
                                               seed=42)

train_data_augmented = train_datagen_augmented.flow_from_directory(train,
                                                                   batch_size=20,
                                                                   target_size=(224, 224),
                                                                   class_mode='categorical',
                                                                   shuffle = True,
                                                                   seed=42)
# Out:
# Found 192 images belonging to 3 classes.
# Found 72 images belonging to 3 classes.
# Found 192 images belonging to 3 classes.

# %%
y_train = train_data.classes
y_val = val_data.classes
y_train_augmented = train_data_augmented.classes

# %%
print(f'Label Number Each Class on Train Data: {train_data.class_indices}')
print(f'Label Number Each Class on Validation Data: {val_data.class_indices}')
print(f'Label Number Each Class on Train Data Augmented: {train_data_augmented.class_indices}')
# Out:
# Label Number Each Class on Train Data: {'blast': 0, 'blight': 1, 'tungro': 2}
# Label Number Each Class on Validation Data: {'blast': 0, 'blight': 1, 'tungro': 2}
# Label Number Each Class on Train Data Augmented: {'blast': 0, 'blight': 1, 'tungro': 2}

# %% [markdown]
# ## Modeling with DenseNet121 as Pre Trained Model

# %%
# Model Definition
dense121 = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
dense121.trainable = False

# %%
# Model Preparation
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(3)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = dense121(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model_dense121 = Model(inputs, outputs)

# %%
# compile model
model_dense121.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# train model
early_stopping = EarlyStopping(patience=3)
history_dense121 = model_dense121.fit(train_data_augmented,
                    epochs=30,
                    validation_data=val_data,
                    )
# Out:
# Epoch 1/30
# 10/10 [==============================] - 27s 2s/step - loss: 1.1340 - accuracy: 0.3490 - val_loss: 1.0497 - val_accuracy: 0.4028
# Epoch 2/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.9429 - accuracy: 0.5521 - val_loss: 0.9355 - val_accuracy: 0.5556
# Epoch 3/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.8408 - accuracy: 0.6719 - val_loss: 0.8045 - val_accuracy: 0.6250
# Epoch 4/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.7444 - accuracy: 0.7448 - val_loss: 0.7618 - val_accuracy: 0.6806
# Epoch 5/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.6619 - accuracy: 0.8177 - val_loss: 0.6443 - val_accuracy: 0.7639
# Epoch 6/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.6080 - accuracy: 0.8333 - val_loss: 0.6164 - val_accuracy: 0.8056
# Epoch 7/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.5539 - accuracy: 0.8542 - val_loss: 0.5432 - val_accuracy: 0.8750
# Epoch 8/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.5180 - accuracy: 0.8698 - val_loss: 0.5016 - val_accuracy: 0.8750
# Epoch 9/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.4529 - accuracy: 0.8906 - val_loss: 0.4623 - val_accuracy: 0.8750
# Epoch 10/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.4422 - accuracy: 0.9062 - val_loss: 0.4417 - val_accuracy: 0.8750
# Epoch 11/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.4204 - accuracy: 0.9219 - val_loss: 0.3966 - val_accuracy: 0.9167
# Epoch 12/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.4094 - accuracy: 0.8958 - val_loss: 0.3845 - val_accuracy: 0.8750
# Epoch 13/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3940 - accuracy: 0.9062 - val_loss: 0.3746 - val_accuracy: 0.8611
# Epoch 14/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.4195 - accuracy: 0.8854 - val_loss: 0.3559 - val_accuracy: 0.8750
# Epoch 15/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3529 - accuracy: 0.9167 - val_loss: 0.3247 - val_accuracy: 0.9444
# Epoch 16/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3131 - accuracy: 0.9323 - val_loss: 0.3201 - val_accuracy: 0.9028
# Epoch 17/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3530 - accuracy: 0.9167 - val_loss: 0.3179 - val_accuracy: 0.9028
# Epoch 18/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3529 - accuracy: 0.9115 - val_loss: 0.3112 - val_accuracy: 0.8889
# Epoch 19/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2987 - accuracy: 0.9271 - val_loss: 0.2481 - val_accuracy: 0.9444
# Epoch 20/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3182 - accuracy: 0.9323 - val_loss: 0.2737 - val_accuracy: 0.9444
# Epoch 21/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.3150 - accuracy: 0.9062 - val_loss: 0.2840 - val_accuracy: 0.9444
# Epoch 22/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2984 - accuracy: 0.9167 - val_loss: 0.2447 - val_accuracy: 0.9444
# Epoch 23/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2446 - accuracy: 0.9427 - val_loss: 0.2584 - val_accuracy: 0.9444
# Epoch 24/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2949 - accuracy: 0.9219 - val_loss: 0.2205 - val_accuracy: 0.9722
# Epoch 25/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2769 - accuracy: 0.9115 - val_loss: 0.2308 - val_accuracy: 0.9583
# Epoch 26/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2475 - accuracy: 0.9531 - val_loss: 0.2407 - val_accuracy: 0.9444
# Epoch 27/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2724 - accuracy: 0.9323 - val_loss: 0.1994 - val_accuracy: 0.9722
# Epoch 28/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2540 - accuracy: 0.9479 - val_loss: 0.2139 - val_accuracy: 0.9444
# Epoch 29/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2282 - accuracy: 0.9375 - val_loss: 0.1936 - val_accuracy: 0.9722
# Epoch 30/30
# 10/10 [==============================] - 16s 2s/step - loss: 0.2680 - accuracy: 0.9583 - val_loss: 0.1833 - val_accuracy: 0.9583

# %% [markdown]
# ## Model Evaluation

# %%
metrics_dense121= pd.DataFrame(history_dense121.history)

figure, ax = plt.subplots (1,2, figsize =(22,5))
metrics_dense121[['loss','val_loss']].plot(ax = ax[0])
ax[0].set_title('Loss Curves')
metrics_dense121[['accuracy','val_accuracy']].plot(ax = ax[1])
ax[1].set_title('Accuracy Curves')
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
y_pred=model_dense121.predict(val_data)
y_pred=np.argmax(y_pred,axis=1)

# %%
print(classification_report(y_pred,y_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        23
#            1       1.00      0.89      0.94        27
#            2       0.92      1.00      0.96        22
#
#     accuracy                           0.96        72
#    macro avg       0.96      0.96      0.96        72
# weighted avg       0.96      0.96      0.96        72

# %%
val_data.class_indices
# Out:
# {'blast': 0, 'blight': 1, 'tungro': 2}

# %%
cm = confusion_matrix(y_pred, y_val)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=val_data.class_indices)
fig, ax = plt.subplots(figsize=(7,7))
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %% [markdown]
# ## Model Inference

# %% [markdown]
# ### Define Each Label's Name

# %%
class_names = ['blast','blight','tungro']

# %% [markdown]
# ### Blast Disease Prediction

# %%
blast1 = load_img('coba/blast_1.jpg', target_size = (224,224))
blast1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1734EC7CC10>

# %%
blast1=img_to_array(blast1) 
blast1=blast1/255.0
prediction_blast1=np.array(blast1)
prediction_blast1= np.expand_dims(blast1, axis=0)

pred_blast1=model_dense121.predict(prediction_blast1)
value = class_names[np.argmax(pred_blast1)]
print ('Prediction is : {}'.format(value))
# Out:
# Prediction is : blast

# %% [markdown]
# ### Blight Disease Prediction

# %%
blight1 = load_img('coba/blight_4.jpg', target_size = (224,224))
blight1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x173469F6790>

# %%
blight1=img_to_array(blight1) 
blight1=blight1/255.0
prediction_blight1=np.array(blight1)
prediction_blight1= np.expand_dims(blight1, axis=0)

pred_blight1=model_dense121.predict(prediction_blight1)
value = class_names[np.argmax(pred_blight1)]
print ('Prediction is : {}'.format(value))
# Out:
# Prediction is : blight

# %% [markdown]
# ### Tungro Disease Prediction

# %%
tungro1 = load_img('coba/tungro_1.jpg', target_size = (224,224))
tungro1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1734699DF70>

# %%
tungro1=img_to_array(tungro1) 
tungro1=tungro1/255.0
prediction_tungro1=np.array(tungro1)
prediction_tungro1= np.expand_dims(tungro1, axis=0)

# %%
pred_tungro1=model_dense121.predict(prediction_tungro1)
value = class_names[np.argmax(pred_tungro1)]
print ('Prediction is : {}'.format(value))
# Out:
# Prediction is : tungro

# %% [markdown]
# ## Save Model with Pretrained Dense121 Model

# %%
tf.keras.models.save_model(
    model_dense121, 'rice_pred_model.hdf5')
